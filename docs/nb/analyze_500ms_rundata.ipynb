# %%
import numpy as np
import uproot
import datetime as dt
from sndaq.analysis import AnalysisHandler, AnalysisConfig
from sndaq.trigger import TriggerHandler

# %% [markdown]
# ## Setup Analyses and Storage

# %%
def nstimes_to_hrtimes(ns_time, year=None):
    """Convert ns since start of year times to human readable (hr) times
    
    ns_time : numpy.array
        Array of times, measured since 01/01/`year` 00:00:00.000 with nanosecond precision
    year : int
        Year corresponding to ns times
        
    Returns
    -------
    dt_start : np.datetime64
        datetime corresponding to start of ns_times (run_start)
    nt_time_norm : numpy.array
        Time bins relative to dt_start in units s, should be uniform 0.5s
    """
    if year is None:
        year = dt.datetime.now().year
    dt_start = np.datetime64(f'{year}-01-01') + np.timedelta64(ns_time[0], 'ns')
    ns_time_norm = (ns_time - ns_time[0]) / 1e9      
    return dt_start, ns_time_norm


def get_500ms_rundata(file, year=None):
    """Get 500ms rundata from sndaq .root file
    
    Parameters
    ----------
    file : string or Pathlike
        Path to SNDAQ data file
    year : int
        Year of run during which data was collected
        
    Returns
    -------
    data : np.ndarray with Dim(n_500ms_bins, n_doms)
        500ms data for all doms
    start : np.datetime64
        Datetime corresponding to start of data 
    time_bins : numpy.array
        Time bins relative to start in units s, should be uniform 0.5s
    """
    with uproot.open(file) as f:
        sn_all = f['sn_all/sn_all_data']
        data = sn_all['data'].array().to_numpy()  # Might hang a little
        gps_time_high = sn_all['SN_Streaming_t/gps_time_high'].array().to_numpy() # First 32 bits of times
        gps_time_low = sn_all['SN_Streaming_t/gps_time_low'].array().to_numpy()  # Last 32 bits of times
        gps_time = np.bitwise_or(np.left_shift(gps_time_high, 32), gps_time_low)
    start, time = nstimes_to_hrtimes(gps_time, year)
    
    return data, start, time

# %%
sndata_file = '../../scratch/data/rundata/SPS/sndata_137104_000.root'
data, start, time = get_500ms_rundata(sndata_file)

idc_dropped = np.where(np.all(data==0, axis=0))[0]
data = np.delete(data, idc_dropped, axis=1)
n_dropped_doms = idc_dropped.size

data.shape
# Out:
# (57608, 5075)

# %%
ndom = 5160 - n_dropped_doms
ana_conf = AnalysisConfig.from_config(conf_path='../..data/config/analysis.config')
ana = AnalysisHandler(config=ana_conf, dropped_doms=idc_dropped)

nbins_window = 400  # 200 s of rates in 0.5s bins
nbins_trigger = int((ana.duration_nosearch + 3*max(ana._binnings)) / 500 - 1)
nbins_fill_trailing = nbins_trigger - int(ana.duration_nosearch/2 /500)
nbins_fill_leading = nbins_trigger - nbins_fill_trailing - nbins_window

dom_bkg_mu = 140
dom_bkg_sig = 22

rate_500ms = np.zeros(shape=(nbins_window, ndom), dtype=np.uint16)
signi = np.zeros(shape=(nbins_window, len(ana.analyses)), dtype=float)

filler = None
np.random.seed(42)

# %% [markdown]
# ## Feeding 500 ms data to PySNDAQ

# %%
# Define a fresh instance for convenience of repeatedly running this cell
ana = AnalysisHandler(config=ana_conf, dropped_doms=idc_dropped)
alert = TriggerHandler()

i = 1
for idx_time, rate in enumerate(data):

    ana.buffer_analysis.append(rate.astype(np.uint32))
    ana.update_analyses()
    ana.process_triggers()

    if ana.trigger_finalized:
        print(f"Candidate: {i}")
        i += 1
        alert.process_trigger(ana.current_trigger)
        ana.current_trigger.reset()
# Out:
# Candidate: 1
# Basic Trigger Processing...
# xi=5.019 in   0.5 +(0.0) s Analysis @t=108.0 s
# Candidate: 2
# Basic Trigger Processing...
# xi=4.645 in   0.5 +(0.0) s Analysis @t=296.0 s
# Candidate: 3
# Basic Trigger Processing...
# xi=5.106 in   0.5 +(0.0) s Analysis @t=329.0 s
# Candidate: 4
# Basic Trigger Processing...
# xi=4.639 in   1.5 +(0.0) s Analysis @t=601.5 s
# Candidate: 5
# Basic Trigger Processing...
# xi=4.120 in   1.5 +(0.0) s Analysis @t=913.5 s
# Candidate: 6
# Basic Trigger Processing...
# xi=4.395 in   1.5 +(1.0) s Analysis @t=998.0 s
# Candidate: 7
# Basic Trigger Processing...
# xi=4.361 in   1.5 +(0.0) s Analysis @t=1071.0 s
# Candidate: 8
# Basic Trigger Processing...
# xi=5.184 in   0.5 +(0.0) s Analysis @t=1471.0 s
# Candidate: 9
# Basic Trigger Processing...
# xi=4.523 in  10.0 +(0.5) s Analysis @t=1589.5 s
# Candidate: 10
# Basic Trigger Processing...
# xi=4.046 in   1.5 +(0.5) s Analysis @t=1652.5 s
# Candidate: 11
# Basic Trigger Processing...
# xi=5.030 in   0.5 +(0.0) s Analysis @t=1956.0 s
# Candidate: 12
# Basic Trigger Processing...
# xi=4.218 in   0.5 +(0.0) s Analysis @t=2046.5 s
# Candidate: 13
# Basic Trigger Processing...
# xi=4.875 in   0.5 +(0.0) s Analysis @t=2135.0 s
# Candidate: 14
# Basic Trigger Processing...
# xi=4.259 in   1.5 +(1.0) s Analysis @t=2271.5 s
# Candidate: 15
# Basic Trigger Processing...
# xi=4.048 in   1.5 +(1.0) s Analysis @t=2334.5 s
# Candidate: 16
# Basic Trigger Processing...
# xi=5.388 in   0.5 +(0.0) s Analysis @t=2440.0 s
# Candidate: 17
# Basic Trigger Processing...
# xi=4.328 in   1.5 +(0.5) s Analysis @t=2516.5 s
# Candidate: 18
# Basic Trigger Processing...
# xi=4.214 in   4.0 +(3.5) s Analysis @t=2736.5 s
# Candidate: 19
# Basic Trigger Processing...
# xi=4.444 in   1.5 +(0.5) s Analysis @t=3232.0 s
# Candidate: 20
# Basic Trigger Processing...
# xi=4.155 in   1.5 +(0.5) s Analysis @t=3322.0 s
# Candidate: 21
# Basic Trigger Processing...
# xi=4.005 in   0.5 +(0.0) s Analysis @t=3359.5 s
# Candidate: 22
# Basic Trigger Processing...
# xi=4.035 in   0.5 +(0.0) s Analysis @t=3391.0 s
# Candidate: 23
# Basic Trigger Processing...
# xi=4.384 in   0.5 +(0.0) s Analysis @t=3526.5 s
# Candidate: 24
# Basic Trigger Processing...
# xi=4.252 in   0.5 +(0.0) s Analysis @t=3565.0 s
# Candidate: 25
# Basic Trigger Processing...
# xi=4.361 in  10.0 +(7.0) s Analysis @t=3663.0 s
# Candidate: 26
# Basic Trigger Processing...
# xi=4.407 in   0.5 +(0.0) s Analysis @t=3888.0 s
# Candidate: 27
# Basic Trigger Processing...
# xi=4.243 in   0.5 +(0.0) s Analysis @t=4064.0 s
# Candidate: 28
# Basic Trigger Processing...
# xi=4.004 in   1.5 +(0.0) s Analysis @t=4162.5 s
# Candidate: 29
# Basic Trigger Processing...
# xi=4.081 in  10.0 +(4.0) s Analysis @t=4196.0 s
# Candidate: 30
# Basic Trigger Processing...
# xi=4.083 in   1.5 +(0.5) s Analysis @t=4256.5 s
# Candidate: 31
# Basic Trigger Processing...
# xi=5.798 in   0.5 +(0.0) s Analysis @t=4397.0 s
# Candidate: 32
# Basic Trigger Processing...
# xi=4.571 in   0.5 +(0.0) s Analysis @t=4608.0 s
# Candidate: 33
# Basic Trigger Processing...
# xi=4.656 in   1.5 +(1.0) s Analysis @t=4641.5 s
# Candidate: 34
# Basic Trigger Processing...
# xi=4.782 in   4.0 +(0.0) s Analysis @t=4684.0 s
# Candidate: 35
# Basic Trigger Processing...
# xi=4.958 in   1.5 +(0.0) s Analysis @t=4816.5 s
# Candidate: 36
# Basic Trigger Processing...
# xi=4.005 in   4.0 +(2.0) s Analysis @t=4890.0 s
# Candidate: 37
# Basic Trigger Processing...
# xi=4.062 in   1.5 +(1.0) s Analysis @t=5289.5 s
# Candidate: 38
# Basic Trigger Processing...
# xi=5.765 in   0.5 +(0.0) s Analysis @t=5523.5 s
# Candidate: 39
# Basic Trigger Processing...
# xi=4.443 in   1.5 +(1.0) s Analysis @t=5588.0 s
# Candidate: 40
# Basic Trigger Processing...
# xi=4.499 in   0.5 +(0.0) s Analysis @t=5694.5 s
# Candidate: 41
# Basic Trigger Processing...
# xi=4.185 in   4.0 +(1.5) s Analysis @t=5734.5 s
# Candidate: 42
# Basic Trigger Processing...
# xi=4.033 in   0.5 +(0.0) s Analysis @t=5861.0 s
# Candidate: 43
# Basic Trigger Processing...
# xi=4.930 in   4.0 +(1.0) s Analysis @t=5907.0 s
# Candidate: 44
# Basic Trigger Processing...
# xi=4.144 in   4.0 +(2.0) s Analysis @t=5946.0 s
# Candidate: 45
# Basic Trigger Processing...
# xi=4.072 in   0.5 +(0.0) s Analysis @t=6203.0 s
# Candidate: 46
# Basic Trigger Processing...
# xi=4.615 in   0.5 +(0.0) s Analysis @t=6339.5 s
# Candidate: 47
# Basic Trigger Processing...
# xi=4.489 in   0.5 +(0.0) s Analysis @t=6724.5 s
# Candidate: 48
# Basic Trigger Processing...
# xi=4.219 in   4.0 +(1.0) s Analysis @t=6835.0 s
# Candidate: 49
# Basic Trigger Processing...
# xi=4.183 in   0.5 +(0.0) s Analysis @t=6871.0 s
# Candidate: 50
# Basic Trigger Processing...
# xi=4.282 in   0.5 +(0.0) s Analysis @t=7069.5 s
# Candidate: 51
# Basic Trigger Processing...
# xi=5.094 in   1.5 +(0.0) s Analysis @t=7165.5 s
# Candidate: 52
# Basic Trigger Processing...
# xi=4.270 in   0.5 +(0.0) s Analysis @t=7277.5 s
# Candidate: 53
# Basic Trigger Processing...
# xi=5.639 in   0.5 +(0.0) s Analysis @t=7377.0 s
# Candidate: 54
# Basic Trigger Processing...
# xi=4.514 in   4.0 +(0.0) s Analysis @t=7608.0 s
# Candidate: 55
# Basic Trigger Processing...
# xi=4.389 in   0.5 +(0.0) s Analysis @t=7735.0 s
# Candidate: 56
# Basic Trigger Processing...
# xi=4.268 in   0.5 +(0.0) s Analysis @t=7793.5 s
# Candidate: 57
# Basic Trigger Processing...
# xi=4.033 in   0.5 +(0.0) s Analysis @t=8142.5 s
# Candidate: 58
# Basic Trigger Processing...
# xi=5.034 in   4.0 +(1.0) s Analysis @t=8263.0 s
# Candidate: 59
# Basic Trigger Processing...
# xi=4.305 in   1.5 +(1.0) s Analysis @t=8312.0 s
# Candidate: 60
# Basic Trigger Processing...
# xi=4.025 in   1.5 +(0.5) s Analysis @t=8372.5 s
# Candidate: 61
# Basic Trigger Processing...
# xi=4.350 in   1.5 +(0.0) s Analysis @t=8491.5 s
# Candidate: 62
# Basic Trigger Processing...
# xi=4.247 in  10.0 +(9.0) s Analysis @t=8821.0 s
# Candidate: 63
# Basic Trigger Processing...
# xi=4.027 in   0.5 +(0.0) s Analysis @t=8980.5 s
# Candidate: 64
# Basic Trigger Processing...
# xi=5.577 in   0.5 +(0.0) s Analysis @t=9053.0 s
# Candidate: 65
# Basic Trigger Processing...
# xi=5.127 in   1.5 +(1.0) s Analysis @t=9170.0 s
# Candidate: 66
# Basic Trigger Processing...
# xi=4.313 in   0.5 +(0.0) s Analysis @t=9204.5 s
# Candidate: 67
# Basic Trigger Processing...
# xi=4.109 in  10.0 +(1.5) s Analysis @t=9388.5 s
# Candidate: 68
# Basic Trigger Processing...
# xi=4.236 in   1.5 +(0.0) s Analysis @t=9480.0 s
# Candidate: 69
# Basic Trigger Processing...
# xi=4.684 in   1.5 +(0.5) s Analysis @t=9517.0 s
# Candidate: 70
# Basic Trigger Processing...
# xi=4.631 in   1.5 +(1.0) s Analysis @t=9615.5 s
# Candidate: 71
# Basic Trigger Processing...
# xi=4.150 in   0.5 +(0.0) s Analysis @t=9815.5 s
# Candidate: 72
# Basic Trigger Processing...
# xi=4.515 in   1.5 +(1.0) s Analysis @t=9921.5 s
# Candidate: 73
# Basic Trigger Processing...
# xi=4.421 in  10.0 +(6.5) s Analysis @t=10053.5 s
# Candidate: 74
# Basic Trigger Processing...
# xi=5.275 in   0.5 +(0.0) s Analysis @t=10207.0 s
# Candidate: 75
# Basic Trigger Processing...
# xi=4.480 in   0.5 +(0.0) s Analysis @t=10292.5 s
# Candidate: 76
# Basic Trigger Processing...
# xi=5.209 in   1.5 +(0.0) s Analysis @t=10429.5 s
# Candidate: 77
# Basic Trigger Processing...
# xi=5.365 in   0.5 +(0.0) s Analysis @t=10549.0 s
# Candidate: 78
# Basic Trigger Processing...
# xi=4.248 in   0.5 +(0.0) s Analysis @t=10620.0 s
# Candidate: 79
# Basic Trigger Processing...
# xi=4.086 in  10.0 +(3.0) s Analysis @t=10647.0 s
# Candidate: 80
# Basic Trigger Processing...
# xi=4.322 in   0.5 +(0.0) s Analysis @t=10725.5 s
# Candidate: 81
# Basic Trigger Processing...
# xi=4.015 in   1.5 +(1.0) s Analysis @t=10773.5 s
# Candidate: 82
# Basic Trigger Processing...
# xi=4.618 in   1.5 +(0.0) s Analysis @t=10978.5 s
# Candidate: 83
# Basic Trigger Processing...
# xi=4.905 in   1.5 +(0.0) s Analysis @t=11349.0 s
# Candidate: 84
# Basic Trigger Processing...
# xi=4.309 in   0.5 +(0.0) s Analysis @t=11611.0 s
# Candidate: 85
# Basic Trigger Processing...
# xi=4.481 in   4.0 +(1.5) s Analysis @t=11702.5 s
# Candidate: 86
# Basic Trigger Processing...
# xi=5.225 in   1.5 +(0.5) s Analysis @t=11761.0 s
# Candidate: 87
# Basic Trigger Processing...
# xi=4.594 in   4.0 +(2.5) s Analysis @t=11833.5 s
# Candidate: 88
# Basic Trigger Processing...
# xi=4.136 in   0.5 +(0.0) s Analysis @t=11880.0 s
# Candidate: 89
# Basic Trigger Processing...
# xi=4.242 in   0.5 +(0.0) s Analysis @t=12031.0 s
# Candidate: 90
# Basic Trigger Processing...
# xi=4.904 in   0.5 +(0.0) s Analysis @t=12191.0 s
# Candidate: 91
# Basic Trigger Processing...
# xi=4.711 in   1.5 +(0.0) s Analysis @t=12384.0 s
# Candidate: 92
# Basic Trigger Processing...
# xi=4.708 in   4.0 +(3.5) s Analysis @t=12524.5 s
# Candidate: 93
# Basic Trigger Processing...
# xi=4.103 in   1.5 +(0.5) s Analysis @t=12718.0 s
# Candidate: 94
# Basic Trigger Processing...
# xi=4.436 in   0.5 +(0.0) s Analysis @t=12812.0 s
# Candidate: 95
# Basic Trigger Processing...
# xi=4.609 in   0.5 +(0.0) s Analysis @t=12843.5 s
# Candidate: 96
# Basic Trigger Processing...
# xi=4.254 in   1.5 +(0.5) s Analysis @t=12887.5 s
# Candidate: 97
# Basic Trigger Processing...
# xi=4.234 in   0.5 +(0.0) s Analysis @t=13441.0 s
# Candidate: 98
# Basic Trigger Processing...
# xi=4.529 in  10.0 +(8.5) s Analysis @t=13461.5 s
# Candidate: 99
# Basic Trigger Processing...
# xi=4.187 in  10.0 +(2.0) s Analysis @t=14018.0 s
# Candidate: 100
# Basic Trigger Processing...
# xi=4.652 in   1.5 +(0.5) s Analysis @t=14167.0 s
# Candidate: 101
# Basic Trigger Processing...
# xi=4.231 in   1.5 +(0.5) s Analysis @t=14285.5 s
# Candidate: 102
# Basic Trigger Processing...
# xi=4.582 in   1.5 +(0.0) s Analysis @t=14326.5 s
# Candidate: 103
# Basic Trigger Processing...
# xi=4.150 in   0.5 +(0.0) s Analysis @t=14367.5 s
# Candidate: 104
# Basic Trigger Processing...
# xi=4.103 in  10.0 +(4.5) s Analysis @t=14455.5 s
# Candidate: 105
# Basic Trigger Processing...
# xi=4.031 in   1.5 +(0.5) s Analysis @t=14573.5 s
# Candidate: 106
# Basic Trigger Processing...
# xi=5.715 in   1.5 +(0.5) s Analysis @t=14627.5 s
# Candidate: 107
# Basic Trigger Processing...
# xi=4.901 in   0.5 +(0.0) s Analysis @t=14675.0 s
# Candidate: 108
# Basic Trigger Processing...
# xi=4.525 in   0.5 +(0.0) s Analysis @t=14769.5 s
# Candidate: 109
# Basic Trigger Processing...
# xi=4.884 in   1.5 +(1.0) s Analysis @t=14867.0 s
# Candidate: 110
# Basic Trigger Processing...
# xi=4.544 in   0.5 +(0.0) s Analysis @t=15069.5 s
# Candidate: 111
# Basic Trigger Processing...
# xi=4.003 in  10.0 +(9.5) s Analysis @t=15450.5 s
# Candidate: 112
# Basic Trigger Processing...
# xi=4.433 in   0.5 +(0.0) s Analysis @t=15531.0 s
# Candidate: 113
# Basic Trigger Processing...
# xi=4.567 in   1.5 +(0.5) s Analysis @t=15596.5 s
# Candidate: 114
# Basic Trigger Processing...
# xi=4.862 in   0.5 +(0.0) s Analysis @t=15691.5 s
# Candidate: 115
# Basic Trigger Processing...
# xi=5.034 in   1.5 +(0.5) s Analysis @t=15754.0 s
# Candidate: 116
# Basic Trigger Processing...
# xi=4.813 in   4.0 +(3.0) s Analysis @t=16053.0 s
# Candidate: 117
# Basic Trigger Processing...
# xi=4.233 in   0.5 +(0.0) s Analysis @t=16223.5 s
# Candidate: 118
# Basic Trigger Processing...
# xi=4.206 in   4.0 +(0.5) s Analysis @t=16355.5 s
# Candidate: 119
# Basic Trigger Processing...
# xi=5.329 in   4.0 +(2.5) s Analysis @t=16589.5 s
# Candidate: 120
# Basic Trigger Processing...
# xi=4.662 in   1.5 +(0.5) s Analysis @t=16645.0 s
# Candidate: 121
# Basic Trigger Processing...
# xi=4.126 in   1.5 +(1.0) s Analysis @t=16757.0 s
# Candidate: 122
# Basic Trigger Processing...
# xi=4.773 in   1.5 +(0.0) s Analysis @t=16974.0 s
# Candidate: 123
# Basic Trigger Processing...
# xi=4.333 in  10.0 +(6.0) s Analysis @t=17214.0 s
# Candidate: 124
# Basic Trigger Processing...
# xi=4.120 in   0.5 +(0.0) s Analysis @t=17385.0 s
# Candidate: 125
# Basic Trigger Processing...
# xi=4.412 in   4.0 +(0.0) s Analysis @t=17552.0 s
# Candidate: 126
# Basic Trigger Processing...
# xi=4.124 in   4.0 +(2.5) s Analysis @t=17805.5 s
# Candidate: 127
# Basic Trigger Processing...
# xi=4.741 in   0.5 +(0.0) s Analysis @t=18061.0 s
# Candidate: 128
# Basic Trigger Processing...
# xi=4.374 in   0.5 +(0.0) s Analysis @t=18336.0 s
# Candidate: 129
# Basic Trigger Processing...
# xi=4.236 in   0.5 +(0.0) s Analysis @t=18445.0 s
# Candidate: 130
# Basic Trigger Processing...
# xi=4.355 in   1.5 +(1.0) s Analysis @t=18504.5 s
# Candidate: 131
# Basic Trigger Processing...
# xi=4.064 in   0.5 +(0.0) s Analysis @t=18550.5 s
# Candidate: 132
# Basic Trigger Processing...
# xi=4.288 in   1.5 +(0.0) s Analysis @t=18627.0 s
# Candidate: 133
# Basic Trigger Processing...
# xi=4.077 in   0.5 +(0.0) s Analysis @t=18811.5 s
# Candidate: 134
# Basic Trigger Processing...
# xi=4.552 in   1.5 +(0.5) s Analysis @t=18931.0 s
# Candidate: 135
# Basic Trigger Processing...
# xi=4.225 in   0.5 +(0.0) s Analysis @t=19137.0 s
# Candidate: 136
# Basic Trigger Processing...
# xi=5.012 in   0.5 +(0.0) s Analysis @t=19400.5 s
# Candidate: 137
# Basic Trigger Processing...
# xi=6.293 in   0.5 +(0.0) s Analysis @t=19556.0 s
# Candidate: 138
# Basic Trigger Processing...
# xi=4.879 in  10.0 +(6.0) s Analysis @t=19814.0 s
# Candidate: 139
# Basic Trigger Processing...
# xi=4.768 in   0.5 +(0.0) s Analysis @t=19923.0 s
# Candidate: 140
# Basic Trigger Processing...
# xi=6.083 in   0.5 +(0.0) s Analysis @t=19962.0 s
# Candidate: 141
# Basic Trigger Processing...
# xi=5.550 in   0.5 +(0.0) s Analysis @t=19998.5 s
# Candidate: 142
# Basic Trigger Processing...
# xi=4.268 in   0.5 +(0.0) s Analysis @t=20034.5 s
# Candidate: 143
# Basic Trigger Processing...
# xi=4.397 in   4.0 +(1.5) s Analysis @t=20138.5 s
# Candidate: 144
# Basic Trigger Processing...
# xi=4.268 in   1.5 +(0.5) s Analysis @t=20180.5 s
# Candidate: 145
# Basic Trigger Processing...
# xi=4.117 in   0.5 +(0.0) s Analysis @t=20580.0 s
# Candidate: 146
# Basic Trigger Processing...
# xi=4.509 in   0.5 +(0.0) s Analysis @t=20673.5 s
# Candidate: 147
# Basic Trigger Processing...
# xi=4.631 in   4.0 +(2.0) s Analysis @t=20946.0 s
# Candidate: 148
# Basic Trigger Processing...
# xi=4.198 in   1.5 +(0.5) s Analysis @t=21043.0 s
# Candidate: 149
# Basic Trigger Processing...
# xi=4.461 in   1.5 +(1.0) s Analysis @t=21194.0 s
# Candidate: 150
# Basic Trigger Processing...
# xi=4.226 in   1.5 +(0.0) s Analysis @t=21502.5 s
# Candidate: 151
# Basic Trigger Processing...
# xi=5.404 in   0.5 +(0.0) s Analysis @t=21566.5 s
# Candidate: 152
# Basic Trigger Processing...
# xi=4.238 in   0.5 +(0.0) s Analysis @t=21840.0 s
# Candidate: 153
# Basic Trigger Processing...
# xi=4.762 in   0.5 +(0.0) s Analysis @t=21976.5 s
# Candidate: 154
# Basic Trigger Processing...
# xi=4.010 in   0.5 +(0.0) s Analysis @t=22080.5 s
# Candidate: 155
# Basic Trigger Processing...
# xi=4.598 in   1.5 +(0.5) s Analysis @t=22211.5 s
# Candidate: 156
# Basic Trigger Processing...
# xi=4.650 in  10.0 +(9.5) s Analysis @t=22260.5 s
# Candidate: 157
# Basic Trigger Processing...
# xi=4.005 in   0.5 +(0.0) s Analysis @t=22394.0 s
# Candidate: 158
# Basic Trigger Processing...
# xi=5.102 in   1.5 +(0.0) s Analysis @t=22467.0 s
# Candidate: 159
# Basic Trigger Processing...
# xi=4.045 in   0.5 +(0.0) s Analysis @t=22803.5 s
# Candidate: 160
# Basic Trigger Processing...
# xi=5.917 in   0.5 +(0.0) s Analysis @t=22855.0 s
# Candidate: 161
# Basic Trigger Processing...
# xi=4.455 in   0.5 +(0.0) s Analysis @t=22909.0 s
# Candidate: 162
# Basic Trigger Processing...
# xi=4.291 in   1.5 +(0.5) s Analysis @t=22946.5 s
# Candidate: 163
# Basic Trigger Processing...
# xi=4.645 in   4.0 +(1.0) s Analysis @t=23035.0 s
# Candidate: 164
# Basic Trigger Processing...
# xi=4.022 in   0.5 +(0.0) s Analysis @t=23104.5 s
# Candidate: 165
# Basic Trigger Processing...
# xi=6.125 in  10.0 +(5.5) s Analysis @t=23264.5 s
# Candidate: 166
# Basic Trigger Processing...
# xi=4.415 in   1.5 +(1.0) s Analysis @t=23403.5 s
# Candidate: 167
# Basic Trigger Processing...
# xi=4.250 in   0.5 +(0.0) s Analysis @t=23461.0 s
# Candidate: 168
# Basic Trigger Processing...
# xi=4.278 in  10.0 +(2.5) s Analysis @t=23917.5 s
# Candidate: 169
# Basic Trigger Processing...
# xi=5.345 in   4.0 +(3.0) s Analysis @t=24269.0 s
# Candidate: 170
# Basic Trigger Processing...
# xi=5.532 in   0.5 +(0.0) s Analysis @t=24750.5 s
# Candidate: 171
# Basic Trigger Processing...
# xi=4.215 in  10.0 +(0.5) s Analysis @t=24779.5 s
# Candidate: 172
# Basic Trigger Processing...
# xi=4.646 in  10.0 +(6.5) s Analysis @t=24833.5 s
# Candidate: 173
# Basic Trigger Processing...
# xi=4.591 in  10.0 +(0.5) s Analysis @t=24929.5 s
# Candidate: 174
# Basic Trigger Processing...
# xi=4.653 in   4.0 +(1.0) s Analysis @t=25203.0 s
# Candidate: 175
# Basic Trigger Processing...
# xi=5.424 in   0.5 +(0.0) s Analysis @t=25285.5 s
# Candidate: 176
# Basic Trigger Processing...
# xi=4.101 in   0.5 +(0.0) s Analysis @t=25335.5 s
# Candidate: 177
# Basic Trigger Processing...
# xi=4.325 in   0.5 +(0.0) s Analysis @t=25389.5 s
# Candidate: 178
# Basic Trigger Processing...
# xi=4.620 in   0.5 +(0.0) s Analysis @t=25461.5 s
# Candidate: 179
# Basic Trigger Processing...
# xi=4.441 in   0.5 +(0.0) s Analysis @t=25573.0 s
# Candidate: 180
# Basic Trigger Processing...
# xi=4.663 in   1.5 +(0.0) s Analysis @t=25735.5 s
# Candidate: 181
# Basic Trigger Processing...
# xi=4.425 in   1.5 +(1.0) s Analysis @t=25790.0 s
# Candidate: 182
# Basic Trigger Processing...
# xi=4.187 in   0.5 +(0.0) s Analysis @t=26014.0 s
# Candidate: 183
# Basic Trigger Processing...
# xi=4.159 in   0.5 +(0.0) s Analysis @t=26050.0 s
# Candidate: 184
# Basic Trigger Processing...
# xi=5.116 in   1.5 +(1.0) s Analysis @t=26193.5 s
# Candidate: 185
# Basic Trigger Processing...
# xi=4.482 in   1.5 +(0.5) s Analysis @t=26447.5 s
# Candidate: 186
# Basic Trigger Processing...
# xi=4.134 in   0.5 +(0.0) s Analysis @t=26506.5 s
# Candidate: 187
# Basic Trigger Processing...
# xi=4.091 in   0.5 +(0.0) s Analysis @t=26639.0 s
# Candidate: 188
# Basic Trigger Processing...
# xi=4.014 in   1.5 +(1.0) s Analysis @t=26717.0 s
# Candidate: 189
# Basic Trigger Processing...
# xi=4.372 in   0.5 +(0.0) s Analysis @t=26837.0 s
# Candidate: 190
# Basic Trigger Processing...
# xi=4.095 in   0.5 +(0.0) s Analysis @t=27093.0 s
# Candidate: 191
# Basic Trigger Processing...
# xi=5.455 in   0.5 +(0.0) s Analysis @t=27180.0 s
# Candidate: 192
# Basic Trigger Processing...
# xi=4.317 in   0.5 +(0.0) s Analysis @t=27282.0 s
# Candidate: 193
# Basic Trigger Processing...
# xi=4.052 in   0.5 +(0.0) s Analysis @t=27462.5 s
# Candidate: 194
# Basic Trigger Processing...
# xi=4.647 in   4.0 +(1.0) s Analysis @t=27615.0 s
# Candidate: 195
# Basic Trigger Processing...
# xi=4.004 in   0.5 +(0.0) s Analysis @t=27665.5 s
# Candidate: 196
# Basic Trigger Processing...
# xi=5.175 in   0.5 +(0.0) s Analysis @t=27733.5 s
# Candidate: 197
# Basic Trigger Processing...
# xi=4.177 in   1.5 +(1.0) s Analysis @t=27789.5 s
# Candidate: 198
# Basic Trigger Processing...
# xi=4.553 in   0.5 +(0.0) s Analysis @t=27837.5 s
# Candidate: 199
# Basic Trigger Processing...
# xi=4.023 in   0.5 +(0.0) s Analysis @t=27895.0 s
# Candidate: 200
# Basic Trigger Processing...
# xi=4.720 in   4.0 +(2.5) s Analysis @t=27921.5 s
# Candidate: 201
# Basic Trigger Processing...
# xi=4.014 in   1.5 +(0.0) s Analysis @t=27966.0 s

# %%
for i, search in enumerate(ana.analyses):
    idc_debug = {
        'eod': search.idx_eod,
        'bgl': search.idx_bgl,
        'exl': search.idx_exl,
        'sw':  search.idx_sw,
        'ext': search.idx_ext,
        'bgt': search.idx_bgt
    }
    
    print(f"\nSearch #{i:<2d} :{search.binsize/1e3:4.1f} +{search.offset/1e3:<4.1f}s")
    for key, val in idc_debug.items():
        print(f"{key:>10s} : {val:<5d}")
# Out:
# Search #0  : 0.5 +0.0 s
#        eod : 1379
#        bgl : 779
#        exl : 719
#         sw : 718
#        ext : 658
#        bgt : 58
#
# Search #1  : 1.5 +0.0 s
#        eod : 1379
#        bgl : 779
#        exl : 719
#         sw : 716
#        ext : 656
#        bgt : 56
#
# Search #2  : 1.5 +0.5 s
#        eod : 1378
#        bgl : 778
#        exl : 718
#         sw : 715
#        ext : 655
#        bgt : 55
#
# Search #3  : 1.5 +1.0 s
#        eod : 1377
#        bgl : 777
#        exl : 717
#         sw : 714
#        ext : 654
#        bgt : 54
#
# Search #4  : 4.0 +0.0 s
#        eod : 1379
#        bgl : 779
#        exl : 719
#         sw : 711
#        ext : 651
#        bgt : 51
#
# Search #5  : 4.0 +0.5 s
#        eod : 1378
#        bgl : 778
#        exl : 718
#         sw : 710
#        ext : 650
#        bgt : 50
#
# Search #6  : 4.0 +1.0 s
#        eod : 1377
#        bgl : 777
#        exl : 717
#         sw : 709
#        ext : 649
#        bgt : 49
#
# Search #7  : 4.0 +1.5 s
#        eod : 1376
#        bgl : 776
#        exl : 716
#         sw : 708
#        ext : 648
#        bgt : 48
#
# Search #8  : 4.0 +2.0 s
#        eod : 1375
#        bgl : 775
#        exl : 715
#         sw : 707
#        ext : 647
#        bgt : 47
#
# Search #9  : 4.0 +2.5 s
#        eod : 1374
#        bgl : 774
#        exl : 714
#         sw : 706
#        ext : 646
#        bgt : 46
#
# Search #10 : 4.0 +3.0 s
#        eod : 1373
#        bgl : 773
#        exl : 713
#         sw : 705
#        ext : 645
#        bgt : 45
#
# Search #11 : 4.0 +3.5 s
#        eod : 1372
#        bgl : 772
#        exl : 712
#         sw : 704
#        ext : 644
#        bgt : 44
#
# Search #12 :10.0 +0.0 s
#        eod : 1379
#        bgl : 779
#        exl : 719
#         sw : 699
#        ext : 639
#        bgt : 39
#
# Search #13 :10.0 +0.5 s
#        eod : 1378
#        bgl : 778
#        exl : 718
#         sw : 698
#        ext : 638
#        bgt : 38
#
# Search #14 :10.0 +1.0 s
#        eod : 1377
#        bgl : 777
#        exl : 717
#         sw : 697
#        ext : 637
#        bgt : 37
#
# Search #15 :10.0 +1.5 s
#        eod : 1376
#        bgl : 776
#        exl : 716
#         sw : 696
#        ext : 636
#        bgt : 36
#
# Search #16 :10.0 +2.0 s
#        eod : 1375
#        bgl : 775
#        exl : 715
#         sw : 695
#        ext : 635
#        bgt : 35
#
# Search #17 :10.0 +2.5 s
#        eod : 1374
#        bgl : 774
#        exl : 714
#         sw : 694
#        ext : 634
#        bgt : 34
#
# Search #18 :10.0 +3.0 s
#        eod : 1373
#        bgl : 773
#        exl : 713
#         sw : 693
#        ext : 633
#        bgt : 33
#
# Search #19 :10.0 +3.5 s
#        eod : 1372
#        bgl : 772
#        exl : 712
#         sw : 692
#        ext : 632
#        bgt : 32
#
# Search #20 :10.0 +4.0 s
#        eod : 1371
#        bgl : 771
#        exl : 711
#         sw : 691
#        ext : 631
#        bgt : 31
#
# Search #21 :10.0 +4.5 s
#        eod : 1370
#        bgl : 770
#        exl : 710
#         sw : 690
#        ext : 630
#        bgt : 30
#
# Search #22 :10.0 +5.0 s
#        eod : 1369
#        bgl : 769
#        exl : 709
#         sw : 689
#        ext : 629
#        bgt : 29
#
# Search #23 :10.0 +5.5 s
#        eod : 1368
#        bgl : 768
#        exl : 708
#         sw : 688
#        ext : 628
#        bgt : 28
#
# Search #24 :10.0 +6.0 s
#        eod : 1367
#        bgl : 767
#        exl : 707
#         sw : 687
#        ext : 627
#        bgt : 27
#
# Search #25 :10.0 +6.5 s
#        eod : 1366
#        bgl : 766
#        exl : 706
#         sw : 686
#        ext : 626
#        bgt : 26
#
# Search #26 :10.0 +7.0 s
#        eod : 1365
#        bgl : 765
#        exl : 705
#         sw : 685
#        ext : 625
#        bgt : 25
#
# Search #27 :10.0 +7.5 s
#        eod : 1364
#        bgl : 764
#        exl : 704
#         sw : 684
#        ext : 624
#        bgt : 24
#
# Search #28 :10.0 +8.0 s
#        eod : 1363
#        bgl : 763
#        exl : 703
#         sw : 683
#        ext : 623
#        bgt : 23
#
# Search #29 :10.0 +8.5 s
#        eod : 1362
#        bgl : 762
#        exl : 702
#         sw : 682
#        ext : 622
#        bgt : 22
#
# Search #30 :10.0 +9.0 s
#        eod : 1361
#        bgl : 761
#        exl : 701
#         sw : 681
#        ext : 621
#        bgt : 21
#
# Search #31 :10.0 +9.5 s
#        eod : 1360
#        bgl : 760
#        exl : 700
#         sw : 680
#        ext : 620
#        bgt : 20

# %%
for i, search in enumerate(ana.analyses):
    idc_debug = {
        'add_bgl': search._idx_addbgl[[0,-1]],
        'sub_bgl': search._idx_subbgl[[0,-1]],
        'add_sw': search._idx_addsw[[0,-1]],
        'sub_sw': search._idx_subsw[[0,-1]],
        'add_bgt': search._idx_addbgt[[0,-1]],
        'sub_bgt':  search._idx_subbgt[[0,-1]],
    }
    
    print(f"\nSearch #{i:<2d} :{search.binsize/1e3:4.1f} +{search.offset/1e3:<4.1f}s")
    for key, val in idc_debug.items():
        print(f"{key:>10s} : {val[0]:>5d} .. {val[1]:<5d}")
# Out:
# Search #0  : 0.5 +0.0 s
#    add_bgl :  1378 .. 1378
#    sub_bgl :   778 .. 778
#     add_sw :   718 .. 718
#     sub_sw :   717 .. 717
#    add_bgt :   657 .. 657
#    sub_bgt :    57 .. 57
#
# Search #1  : 1.5 +0.0 s
#    add_bgl :  1376 .. 1378
#    sub_bgl :   776 .. 778
#     add_sw :   716 .. 718
#     sub_sw :   713 .. 715
#    add_bgt :   653 .. 655
#    sub_bgt :    53 .. 55
#
# Search #2  : 1.5 +0.5 s
#    add_bgl :  1375 .. 1377
#    sub_bgl :   775 .. 777
#     add_sw :   715 .. 717
#     sub_sw :   712 .. 714
#    add_bgt :   652 .. 654
#    sub_bgt :    52 .. 54
#
# Search #3  : 1.5 +1.0 s
#    add_bgl :  1374 .. 1376
#    sub_bgl :   774 .. 776
#     add_sw :   714 .. 716
#     sub_sw :   711 .. 713
#    add_bgt :   651 .. 653
#    sub_bgt :    51 .. 53
#
# Search #4  : 4.0 +0.0 s
#    add_bgl :  1371 .. 1378
#    sub_bgl :   771 .. 778
#     add_sw :   711 .. 718
#     sub_sw :   703 .. 710
#    add_bgt :   643 .. 650
#    sub_bgt :    43 .. 50
#
# Search #5  : 4.0 +0.5 s
#    add_bgl :  1370 .. 1377
#    sub_bgl :   770 .. 777
#     add_sw :   710 .. 717
#     sub_sw :   702 .. 709
#    add_bgt :   642 .. 649
#    sub_bgt :    42 .. 49
#
# Search #6  : 4.0 +1.0 s
#    add_bgl :  1369 .. 1376
#    sub_bgl :   769 .. 776
#     add_sw :   709 .. 716
#     sub_sw :   701 .. 708
#    add_bgt :   641 .. 648
#    sub_bgt :    41 .. 48
#
# Search #7  : 4.0 +1.5 s
#    add_bgl :  1368 .. 1375
#    sub_bgl :   768 .. 775
#     add_sw :   708 .. 715
#     sub_sw :   700 .. 707
#    add_bgt :   640 .. 647
#    sub_bgt :    40 .. 47
#
# Search #8  : 4.0 +2.0 s
#    add_bgl :  1367 .. 1374
#    sub_bgl :   767 .. 774
#     add_sw :   707 .. 714
#     sub_sw :   699 .. 706
#    add_bgt :   639 .. 646
#    sub_bgt :    39 .. 46
#
# Search #9  : 4.0 +2.5 s
#    add_bgl :  1366 .. 1373
#    sub_bgl :   766 .. 773
#     add_sw :   706 .. 713
#     sub_sw :   698 .. 705
#    add_bgt :   638 .. 645
#    sub_bgt :    38 .. 45
#
# Search #10 : 4.0 +3.0 s
#    add_bgl :  1365 .. 1372
#    sub_bgl :   765 .. 772
#     add_sw :   705 .. 712
#     sub_sw :   697 .. 704
#    add_bgt :   637 .. 644
#    sub_bgt :    37 .. 44
#
# Search #11 : 4.0 +3.5 s
#    add_bgl :  1364 .. 1371
#    sub_bgl :   764 .. 771
#     add_sw :   704 .. 711
#     sub_sw :   696 .. 703
#    add_bgt :   636 .. 643
#    sub_bgt :    36 .. 43
#
# Search #12 :10.0 +0.0 s
#    add_bgl :  1359 .. 1378
#    sub_bgl :   759 .. 778
#     add_sw :   699 .. 718
#     sub_sw :   679 .. 698
#    add_bgt :   619 .. 638
#    sub_bgt :    19 .. 38
#
# Search #13 :10.0 +0.5 s
#    add_bgl :  1358 .. 1377
#    sub_bgl :   758 .. 777
#     add_sw :   698 .. 717
#     sub_sw :   678 .. 697
#    add_bgt :   618 .. 637
#    sub_bgt :    18 .. 37
#
# Search #14 :10.0 +1.0 s
#    add_bgl :  1357 .. 1376
#    sub_bgl :   757 .. 776
#     add_sw :   697 .. 716
#     sub_sw :   677 .. 696
#    add_bgt :   617 .. 636
#    sub_bgt :    17 .. 36
#
# Search #15 :10.0 +1.5 s
#    add_bgl :  1356 .. 1375
#    sub_bgl :   756 .. 775
#     add_sw :   696 .. 715
#     sub_sw :   676 .. 695
#    add_bgt :   616 .. 635
#    sub_bgt :    16 .. 35
#
# Search #16 :10.0 +2.0 s
#    add_bgl :  1355 .. 1374
#    sub_bgl :   755 .. 774
#     add_sw :   695 .. 714
#     sub_sw :   675 .. 694
#    add_bgt :   615 .. 634
#    sub_bgt :    15 .. 34
#
# Search #17 :10.0 +2.5 s
#    add_bgl :  1354 .. 1373
#    sub_bgl :   754 .. 773
#     add_sw :   694 .. 713
#     sub_sw :   674 .. 693
#    add_bgt :   614 .. 633
#    sub_bgt :    14 .. 33
#
# Search #18 :10.0 +3.0 s
#    add_bgl :  1353 .. 1372
#    sub_bgl :   753 .. 772
#     add_sw :   693 .. 712
#     sub_sw :   673 .. 692
#    add_bgt :   613 .. 632
#    sub_bgt :    13 .. 32
#
# Search #19 :10.0 +3.5 s
#    add_bgl :  1352 .. 1371
#    sub_bgl :   752 .. 771
#     add_sw :   692 .. 711
#     sub_sw :   672 .. 691
#    add_bgt :   612 .. 631
#    sub_bgt :    12 .. 31
#
# Search #20 :10.0 +4.0 s
#    add_bgl :  1351 .. 1370
#    sub_bgl :   751 .. 770
#     add_sw :   691 .. 710
#     sub_sw :   671 .. 690
#    add_bgt :   611 .. 630
#    sub_bgt :    11 .. 30
#
# Search #21 :10.0 +4.5 s
#    add_bgl :  1350 .. 1369
#    sub_bgl :   750 .. 769
#     add_sw :   690 .. 709
#     sub_sw :   670 .. 689
#    add_bgt :   610 .. 629
#    sub_bgt :    10 .. 29
#
# Search #22 :10.0 +5.0 s
#    add_bgl :  1349 .. 1368
#    sub_bgl :   749 .. 768
#     add_sw :   689 .. 708
#     sub_sw :   669 .. 688
#    add_bgt :   609 .. 628
#    sub_bgt :     9 .. 28
#
# Search #23 :10.0 +5.5 s
#    add_bgl :  1348 .. 1367
#    sub_bgl :   748 .. 767
#     add_sw :   688 .. 707
#     sub_sw :   668 .. 687
#    add_bgt :   608 .. 627
#    sub_bgt :     8 .. 27
#
# Search #24 :10.0 +6.0 s
#    add_bgl :  1347 .. 1366
#    sub_bgl :   747 .. 766
#     add_sw :   687 .. 706
#     sub_sw :   667 .. 686
#    add_bgt :   607 .. 626
#    sub_bgt :     7 .. 26
#
# Search #25 :10.0 +6.5 s
#    add_bgl :  1346 .. 1365
#    sub_bgl :   746 .. 765
#     add_sw :   686 .. 705
#     sub_sw :   666 .. 685
#    add_bgt :   606 .. 625
#    sub_bgt :     6 .. 25
#
# Search #26 :10.0 +7.0 s
#    add_bgl :  1345 .. 1364
#    sub_bgl :   745 .. 764
#     add_sw :   685 .. 704
#     sub_sw :   665 .. 684
#    add_bgt :   605 .. 624
#    sub_bgt :     5 .. 24
#
# Search #27 :10.0 +7.5 s
#    add_bgl :  1344 .. 1363
#    sub_bgl :   744 .. 763
#     add_sw :   684 .. 703
#     sub_sw :   664 .. 683
#    add_bgt :   604 .. 623
#    sub_bgt :     4 .. 23
#
# Search #28 :10.0 +8.0 s
#    add_bgl :  1343 .. 1362
#    sub_bgl :   743 .. 762
#     add_sw :   683 .. 702
#     sub_sw :   663 .. 682
#    add_bgt :   603 .. 622
#    sub_bgt :     3 .. 22
#
# Search #29 :10.0 +8.5 s
#    add_bgl :  1342 .. 1361
#    sub_bgl :   742 .. 761
#     add_sw :   682 .. 701
#     sub_sw :   662 .. 681
#    add_bgt :   602 .. 621
#    sub_bgt :     2 .. 21
#
# Search #30 :10.0 +9.0 s
#    add_bgl :  1341 .. 1360
#    sub_bgl :   741 .. 760
#     add_sw :   681 .. 700
#     sub_sw :   661 .. 680
#    add_bgt :   601 .. 620
#    sub_bgt :     1 .. 20
#
# Search #31 :10.0 +9.5 s
#    add_bgl :  1340 .. 1359
#    sub_bgl :   740 .. 759
#     add_sw :   680 .. 699
#     sub_sw :   660 .. 679
#    add_bgt :   600 .. 619
#    sub_bgt :     0 .. 19

# %%
for i, (analysis, xi) in enumerate(zip(ana.analyses, signi.T), start=1):
    print(f"\nSearch #{i:<2d}: {analysis.binsize/1e3:<4.1f} +{analysis.offset/1e3:<4.1f}s\n"
          f"   max xi : {xi.max():4.2f}  @ bin t={xi.argmax()*0.5}s from window start")
# Out:
# Search #1 : 1.0  +0.0 s
#    max xi : 2.70  @ bin t=36.5s from window start
#
# Search #2 : 1.0  +0.5 s
#    max xi : 2.54  @ bin t=8.5s from window start
