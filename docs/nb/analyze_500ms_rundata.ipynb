# %%
import numpy as np
import uproot
import datetime as dt
from sndaq.analysis import AnalysisHandler, AnalysisConfig
from sndaq.trigger import TriggerHandler
from sndaq.util.legacy import get_sndata_file
from pathlib import Path
import os

# %% [markdown]
# ## Setup Analyses and Storage

# %%
def nstimes_to_hrtimes(ns_time, year=None):
    """Convert ns since start of year times to human readable (hr) times
    
    ns_time : numpy.array
        Array of times, measured since 01/01/`year` 00:00:00.000 with nanosecond precision
    year : int
        Year corresponding to ns times
        
    Returns
    -------
    dt_start : np.datetime64
        datetime corresponding to start of ns_times (run_start)
    nt_time_norm : numpy.array
        Time bins relative to dt_start in units s, should be uniform 0.5s
    """
    if year is None:
        year = dt.datetime.now().year
    dt_start = np.datetime64(f'{year}-01-01') + np.timedelta64(ns_time[0], 'ns')
    ns_time_norm = (ns_time - ns_time[0]) / 1e9      
    return dt_start, ns_time_norm


def get_500ms_rundata(file, year=None):
    """Get 500ms rundata from sndaq .root file
    
    Parameters
    ----------
    file : string or Pathlike
        Path to SNDAQ data file
    year : int
        Year of run during which data was collected
        
    Returns
    -------
    data : np.ndarray with Dim(n_500ms_bins, n_doms)
        500ms data for all doms
    start : np.datetime64
        Datetime corresponding to start of data 
    time_bins : numpy.array
        Time bins relative to start in units s, should be uniform 0.5s
    """
    if ''.join(Path(file).suffixes) == '.tar.gz':
        tarball_path = Path(file)
        parent_dir = tarball_path.parent
        sndata_rootfile = str(tarball_path).rstrip(''.join(tarball_path.suffixes))+'.root'
        
        if os.path.exists(sndata_rootfile):
            print(f'Provided path to {file} \n\tbut found extracted {os.path.basename(sndata_rootfile)} '+
                  'in the same directory. Switching to ROOT file.')
            
        else:
            if os.path.exists(file):
                print(f'Extracting ROOT file {os.path.basename(rootfile)} from file: {file}')
                with tarfile.open(file) as tf:
                    tf.extract(os.path.basename(rootfile), path=parent_dir)
            else:
                raise FileNotFoundError(f"No SN Data file {file} found!")
        file = sndata_rootfile        
    
    with uproot.open(file) as f:
        sn_all = f['sn_all/sn_all_data']
        data = sn_all['data'].array().to_numpy()  # Might hang a little
        gps_time_high = sn_all['SN_Streaming_t/gps_time_high'].array().to_numpy() # First 32 bits of times
        gps_time_low = sn_all['SN_Streaming_t/gps_time_low'].array().to_numpy()  # Last 32 bits of times
        gps_time = np.bitwise_or(np.left_shift(gps_time_high, 32), gps_time_low)
    start, time = nstimes_to_hrtimes(gps_time, year)
    
    return data, start, time

# %%
sndata_file = get_sndata_file(137104, USER_live='icecube', PASS_live='skua', USER_ldap='sgriswold',
                              cache_dir = '../../../scratch/data/rundata/SPS/')[0]
data, start, time = get_500ms_rundata(sndata_file)

idc_dropped = np.where(np.all(data==0, axis=0))[0]
data = np.delete(data, idc_dropped, axis=1)
n_dropped_doms = idc_dropped.size

print(f"\nLoaded {data.shape[0] * 0.5} s of data ({data.shape[0]} bins) for {data.shape[1]} DOMs")
# Out:
# Found SN Data file(s): ../../../scratch/data/rundata/SPS/sndata_137104_000.tar.gz
# Provided path to ../../../scratch/data/rundata/SPS/sndata_137104_000.tar.gz
# 	but found extracted sndata_137104_000.root in the same directory. Switching to ROOT file.
#
# Loaded 28804.0 s of data (57608 bins) for 5075 DOMs

# %%
ndom = 5160 - n_dropped_doms
ana_conf = AnalysisConfig.from_config(conf_path='../../data/config/analysis.config')
ana = AnalysisHandler(config=ana_conf, dropped_doms=idc_dropped)

nbins_window = 400  # 200 s of rates in 0.5s bins
nbins_trigger = int((ana.config.duration_nosearch + 3*max(ana._binnings)) / 500 - 1)
nbins_fill_trailing = nbins_trigger - int(ana.config.duration_nosearch/2 /500)
nbins_fill_leading = nbins_trigger - nbins_fill_trailing - nbins_window

dom_bkg_mu = 140
dom_bkg_sig = 22

rate_500ms = np.zeros(shape=(nbins_window, ndom), dtype=np.uint16)
signi = np.zeros(shape=(nbins_window, len(ana.analyses)), dtype=float)

filler = None
np.random.seed(42)

# %% [markdown]
# ## Feeding 500 ms data to PySNDAQ

# %%
# Define a fresh instance for convenience of repeatedly running this cell
ana = AnalysisHandler(config=ana_conf, dropped_doms=idc_dropped)
alert = TriggerHandler()

for idx_time, rate in enumerate(data):

    ana.buffer_analysis.append(rate.astype(np.uint32))
    ana.update_analyses()
    ana.process_triggers()

    if ana.trigger_finalized:
        ana.cand_count += 1
        alert.process_trigger(ana.current_trigger)
        ana.current_trigger.reset()
        ana.trigger_count = 0
        print('')
# Out:
# Primary Trigger Processing...
# Candidate   1, Trigger   1: xi=5.003 in   0.5 +(0.0) s Analysis @t=123.0 s
#
# Primary Trigger Processing...
# Candidate   2, Trigger   1: xi=4.622 in   0.5 +(0.0) s Analysis @t=311.0 s
#
# Primary Trigger Processing...
# Candidate   3, Trigger   1: xi=5.091 in   0.5 +(0.0) s Analysis @t=344.0 s
#
# Primary Trigger Processing...
# Candidate   4, Trigger   3: xi=4.603 in   1.5 +(0.0) s Analysis @t=616.5 s
#
# Primary Trigger Processing...
# Candidate   5, Trigger   1: xi=4.116 in   1.5 +(0.0) s Analysis @t=928.5 s
#
# Primary Trigger Processing...
# Candidate   6, Trigger   1: xi=4.022 in   1.5 +(0.0) s Analysis @t=963.0 s
#
# Primary Trigger Processing...
# Candidate   7, Trigger   1: xi=4.367 in   1.5 +(1.0) s Analysis @t=1013.0 s
#
# Primary Trigger Processing...
# Candidate   8, Trigger   1: xi=4.378 in   1.5 +(0.0) s Analysis @t=1086.0 s
#
# Primary Trigger Processing...
# Candidate   9, Trigger   1: xi=5.175 in   0.5 +(0.0) s Analysis @t=1486.0 s
#
# Primary Trigger Processing...
# Candidate  10, Trigger   3: xi=4.257 in  10.0 +(7.0) s Analysis @t=1603.0 s
#
# Primary Trigger Processing...
# Candidate  11, Trigger   1: xi=4.051 in   1.5 +(0.5) s Analysis @t=1667.5 s
#
# Primary Trigger Processing...
# Candidate  12, Trigger   1: xi=5.037 in   0.5 +(0.0) s Analysis @t=1971.0 s
#
# Primary Trigger Processing...
# Candidate  13, Trigger   1: xi=4.214 in   0.5 +(0.0) s Analysis @t=2061.5 s
#
# Primary Trigger Processing...
# Candidate  14, Trigger   1: xi=4.874 in   0.5 +(0.0) s Analysis @t=2150.0 s
#
# Primary Trigger Processing...
# Candidate  15, Trigger   1: xi=4.228 in   1.5 +(1.0) s Analysis @t=2286.5 s
#
# Primary Trigger Processing...
# Candidate  16, Trigger   2: xi=4.056 in   1.5 +(1.0) s Analysis @t=2349.5 s
#
# Primary Trigger Processing...
# Candidate  17, Trigger   1: xi=5.381 in   0.5 +(0.0) s Analysis @t=2455.0 s
#
# Primary Trigger Processing...
# Candidate  18, Trigger   1: xi=4.346 in   1.5 +(0.5) s Analysis @t=2531.5 s
#
# Primary Trigger Processing...
# Candidate  19, Trigger   1: xi=4.247 in   4.0 +(2.5) s Analysis @t=2751.5 s
#
# Primary Trigger Processing...
# Candidate  20, Trigger   2: xi=4.453 in   1.5 +(0.5) s Analysis @t=3247.0 s
#
# Primary Trigger Processing...
# Candidate  21, Trigger   1: xi=4.231 in   1.5 +(0.5) s Analysis @t=3337.0 s
#
# Primary Trigger Processing...
# Candidate  22, Trigger   1: xi=4.012 in   0.5 +(0.0) s Analysis @t=3374.5 s
#
# Primary Trigger Processing...
# Candidate  23, Trigger   1: xi=4.004 in   0.5 +(0.0) s Analysis @t=3406.0 s
#
# Primary Trigger Processing...
# Candidate  24, Trigger   1: xi=4.370 in   0.5 +(0.0) s Analysis @t=3541.5 s
#
# Primary Trigger Processing...
# Candidate  25, Trigger   1: xi=4.259 in   0.5 +(0.0) s Analysis @t=3580.0 s
#
# Primary Trigger Processing...
# Candidate  26, Trigger   1: xi=4.293 in   0.5 +(0.0) s Analysis @t=3682.5 s
#
# Primary Trigger Processing...
# Candidate  27, Trigger   2: xi=4.403 in   0.5 +(0.0) s Analysis @t=3903.0 s
#
# Primary Trigger Processing...
# Candidate  28, Trigger   1: xi=4.220 in   0.5 +(0.0) s Analysis @t=4079.0 s
#
# Primary Trigger Processing...
# Candidate  29, Trigger   1: xi=4.257 in  10.0 +(9.0) s Analysis @t=4211.0 s
#
# Primary Trigger Processing...
# Candidate  30, Trigger   1: xi=4.073 in   1.5 +(0.5) s Analysis @t=4271.5 s
#
# Primary Trigger Processing...
# Candidate  31, Trigger   1: xi=5.797 in   0.5 +(0.0) s Analysis @t=4412.0 s
#
# Primary Trigger Processing...
# Candidate  32, Trigger   2: xi=4.562 in   0.5 +(0.0) s Analysis @t=4623.0 s
#
# Primary Trigger Processing...
# Candidate  33, Trigger   1: xi=4.625 in   1.5 +(1.0) s Analysis @t=4656.5 s
#
# Primary Trigger Processing...
# Candidate  34, Trigger   2: xi=4.838 in   4.0 +(3.0) s Analysis @t=4699.0 s
#
# Primary Trigger Processing...
# Candidate  35, Trigger   1: xi=4.946 in   1.5 +(0.0) s Analysis @t=4831.5 s
#
# Primary Trigger Processing...
# Candidate  36, Trigger   1: xi=4.050 in   4.0 +(1.0) s Analysis @t=4905.0 s
#
# Primary Trigger Processing...
# Candidate  37, Trigger   1: xi=4.019 in   1.5 +(0.0) s Analysis @t=4953.0 s
#
# Primary Trigger Processing...
# Candidate  38, Trigger   1: xi=4.037 in   1.5 +(1.0) s Analysis @t=5304.5 s
#
# Primary Trigger Processing...
# Candidate  39, Trigger   1: xi=5.759 in   0.5 +(0.0) s Analysis @t=5538.5 s
#
# Primary Trigger Processing...
# Candidate  40, Trigger   1: xi=4.456 in   1.5 +(1.0) s Analysis @t=5603.0 s
#
# Primary Trigger Processing...
# Candidate  41, Trigger   1: xi=4.500 in   0.5 +(0.0) s Analysis @t=5709.5 s
#
# Primary Trigger Processing...
# Candidate  42, Trigger   1: xi=4.110 in   4.0 +(0.5) s Analysis @t=5749.5 s
#
# Primary Trigger Processing...
# Candidate  43, Trigger   1: xi=4.050 in   0.5 +(0.0) s Analysis @t=5876.0 s
#
# Primary Trigger Processing...
# Candidate  44, Trigger   2: xi=4.805 in   4.0 +(0.0) s Analysis @t=5922.0 s
#
# Primary Trigger Processing...
# Candidate  45, Trigger   1: xi=4.159 in   4.0 +(1.0) s Analysis @t=5961.0 s
#
# Primary Trigger Processing...
# Candidate  46, Trigger   1: xi=4.352 in  10.0 +(6.0) s Analysis @t=6074.0 s
#
# Primary Trigger Processing...
# Candidate  47, Trigger   1: xi=4.078 in   0.5 +(0.0) s Analysis @t=6218.0 s
#
# Primary Trigger Processing...
# Candidate  48, Trigger   2: xi=4.632 in   0.5 +(0.0) s Analysis @t=6354.5 s
#
# Primary Trigger Processing...
# Candidate  49, Trigger   1: xi=4.118 in  10.0 +(5.5) s Analysis @t=6434.5 s
#
# Primary Trigger Processing...
# Candidate  50, Trigger   1: xi=4.504 in   0.5 +(0.0) s Analysis @t=6739.5 s
#
# Primary Trigger Processing...
# Candidate  51, Trigger   1: xi=4.323 in   4.0 +(0.0) s Analysis @t=6850.0 s
#
# Primary Trigger Processing...
# Candidate  52, Trigger   1: xi=4.186 in   0.5 +(0.0) s Analysis @t=6886.0 s
#
# Primary Trigger Processing...
# Candidate  53, Trigger   1: xi=4.295 in   0.5 +(0.0) s Analysis @t=7084.5 s
#
# Primary Trigger Processing...
# Candidate  54, Trigger   3: xi=5.122 in   1.5 +(0.0) s Analysis @t=7180.5 s
#
# Primary Trigger Processing...
# Candidate  55, Trigger   2: xi=4.276 in   0.5 +(0.0) s Analysis @t=7292.5 s
#
# Primary Trigger Processing...
# Candidate  56, Trigger   1: xi=5.650 in   0.5 +(0.0) s Analysis @t=7392.0 s
#
# Primary Trigger Processing...
# Candidate  57, Trigger   3: xi=4.538 in   4.0 +(3.0) s Analysis @t=7623.0 s
#
# Primary Trigger Processing...
# Candidate  58, Trigger   1: xi=4.424 in   0.5 +(0.0) s Analysis @t=7750.0 s
#
# Primary Trigger Processing...
# Candidate  59, Trigger   1: xi=4.277 in   0.5 +(0.0) s Analysis @t=7808.5 s
#
# Primary Trigger Processing...
# Candidate  60, Trigger   1: xi=4.053 in   0.5 +(0.0) s Analysis @t=8157.5 s
#
# Primary Trigger Processing...
# Candidate  61, Trigger   1: xi=4.693 in   4.0 +(0.0) s Analysis @t=8278.0 s
#
# Primary Trigger Processing...
# Candidate  62, Trigger   1: xi=4.272 in   1.5 +(1.0) s Analysis @t=8327.0 s
#
# Primary Trigger Processing...
# Candidate  63, Trigger   1: xi=4.047 in   1.5 +(0.5) s Analysis @t=8387.5 s
#
# Primary Trigger Processing...
# Candidate  64, Trigger   1: xi=4.320 in   1.5 +(0.0) s Analysis @t=8506.5 s
#
# Primary Trigger Processing...
# Candidate  65, Trigger   2: xi=4.176 in  10.0 +(4.0) s Analysis @t=8836.0 s
#
# Primary Trigger Processing...
# Candidate  66, Trigger   1: xi=4.005 in   0.5 +(0.0) s Analysis @t=8995.5 s
#
# Primary Trigger Processing...
# Candidate  67, Trigger   1: xi=5.582 in   0.5 +(0.0) s Analysis @t=9068.0 s
#
# Primary Trigger Processing...
# Candidate  68, Trigger   1: xi=5.116 in   1.5 +(1.0) s Analysis @t=9185.0 s
#
# Primary Trigger Processing...
# Candidate  69, Trigger   1: xi=4.305 in   0.5 +(0.0) s Analysis @t=9219.5 s
#
# Primary Trigger Processing...
# Candidate  70, Trigger   1: xi=4.245 in   1.5 +(0.0) s Analysis @t=9495.0 s
#
# Primary Trigger Processing...
# Candidate  71, Trigger   1: xi=4.738 in   1.5 +(0.5) s Analysis @t=9532.0 s
#
# Primary Trigger Processing...
# Candidate  72, Trigger   1: xi=4.690 in   1.5 +(1.0) s Analysis @t=9630.5 s
#
# Primary Trigger Processing...
# Candidate  73, Trigger   1: xi=4.143 in   0.5 +(0.0) s Analysis @t=9830.5 s
#
# Primary Trigger Processing...
# Candidate  74, Trigger   1: xi=4.516 in   1.5 +(1.0) s Analysis @t=9936.5 s
#
# Primary Trigger Processing...
# Candidate  75, Trigger   3: xi=4.501 in  10.0 +(1.5) s Analysis @t=10068.5 s
#
# Primary Trigger Processing...
# Candidate  76, Trigger   2: xi=5.268 in   0.5 +(0.0) s Analysis @t=10222.0 s
#
# Primary Trigger Processing...
# Candidate  77, Trigger   2: xi=4.452 in   0.5 +(0.0) s Analysis @t=10307.5 s
# Primary Trigger Processing...
# Candidate  78, Trigger   2: xi=5.116 in   1.5 +(0.0) s Analysis @t=10444.5 s
#
# Primary Trigger Processing...
# Candidate  79, Trigger   2: xi=5.362 in   0.5 +(0.0) s Analysis @t=10564.0 s
#
# Primary Trigger Processing...
# Candidate  80, Trigger   1: xi=4.237 in   0.5 +(0.0) s Analysis @t=10635.0 s
#
# Primary Trigger Processing...
# Candidate  81, Trigger   1: xi=4.304 in   0.5 +(0.0) s Analysis @t=10740.5 s
#
# Primary Trigger Processing...
# Candidate  82, Trigger   1: xi=4.027 in   1.5 +(1.0) s Analysis @t=10788.5 s
#
# Primary Trigger Processing...
# Candidate  83, Trigger   1: xi=4.650 in   1.5 +(0.0) s Analysis @t=10993.5 s
#
# Primary Trigger Processing...
# Candidate  84, Trigger   2: xi=4.902 in   1.5 +(0.0) s Analysis @t=11364.0 s
#
# Primary Trigger Processing...
# Candidate  85, Trigger   1: xi=4.369 in   0.5 +(0.0) s Analysis @t=11626.0 s
#
# Primary Trigger Processing...
# Candidate  86, Trigger   1: xi=4.368 in   4.0 +(0.5) s Analysis @t=11717.5 s
#
# Primary Trigger Processing...
# Candidate  87, Trigger   2: xi=5.250 in   1.5 +(0.5) s Analysis @t=11776.0 s
#
# Primary Trigger Processing...
# Candidate  88, Trigger   1: xi=4.537 in   4.0 +(1.5) s Analysis @t=11848.5 s
#
# Primary Trigger Processing...
# Candidate  89, Trigger   1: xi=4.155 in   0.5 +(0.0) s Analysis @t=11895.0 s
#
# Primary Trigger Processing...
# Candidate  90, Trigger   1: xi=4.205 in   0.5 +(0.0) s Analysis @t=12046.0 s
#
# Primary Trigger Processing...
# Candidate  91, Trigger   1: xi=4.896 in   0.5 +(0.0) s Analysis @t=12206.0 s
#
# Primary Trigger Processing...
# Candidate  92, Trigger   1: xi=4.720 in   1.5 +(0.0) s Analysis @t=12399.0 s
#
# Primary Trigger Processing...
# Candidate  93, Trigger   2: xi=4.695 in   4.0 +(2.5) s Analysis @t=12539.5 s
#
# Primary Trigger Processing...
# Candidate  94, Trigger   1: xi=4.005 in   4.0 +(2.5) s Analysis @t=12683.5 s
#
# Primary Trigger Processing...
# Candidate  95, Trigger   1: xi=4.064 in   1.5 +(0.5) s Analysis @t=12733.0 s
#
# Primary Trigger Processing...
# Candidate  96, Trigger   2: xi=4.449 in   0.5 +(0.0) s Analysis @t=12827.0 s
#
# Primary Trigger Processing...
# Candidate  97, Trigger   1: xi=4.609 in   0.5 +(0.0) s Analysis @t=12858.5 s
#
# Primary Trigger Processing...
# Candidate  98, Trigger   2: xi=4.235 in   1.5 +(0.5) s Analysis @t=12902.5 s
#
# Primary Trigger Processing...
# Candidate  99, Trigger   1: xi=4.216 in   0.5 +(0.0) s Analysis @t=13456.0 s
#
# Primary Trigger Processing...
# Candidate 100, Trigger   1: xi=4.228 in  10.0 +(3.5) s Analysis @t=13476.5 s
#
# Primary Trigger Processing...
# Candidate 101, Trigger   1: xi=4.274 in  10.0 +(6.5) s Analysis @t=14033.5 s
#
# Primary Trigger Processing...
# Candidate 102, Trigger   1: xi=4.656 in   1.5 +(0.5) s Analysis @t=14182.0 s
#
# Primary Trigger Processing...
# Candidate 103, Trigger   2: xi=4.213 in   1.5 +(0.5) s Analysis @t=14300.5 s
#
# Primary Trigger Processing...
# Candidate 104, Trigger   1: xi=4.568 in   1.5 +(0.0) s Analysis @t=14341.5 s
#
# Primary Trigger Processing...
# Candidate 105, Trigger   1: xi=4.138 in   0.5 +(0.0) s Analysis @t=14382.5 s
#
# Primary Trigger Processing...
# Candidate 106, Trigger   1: xi=4.063 in  10.0 +(9.5) s Analysis @t=14470.5 s
#
# Primary Trigger Processing...
# Candidate 107, Trigger   2: xi=4.129 in   4.0 +(1.5) s Analysis @t=14588.5 s
#
# Primary Trigger Processing...
# Candidate 108, Trigger   1: xi=5.735 in   1.5 +(0.5) s Analysis @t=14642.5 s
#
# Primary Trigger Processing...
# Candidate 109, Trigger   1: xi=4.878 in   0.5 +(0.0) s Analysis @t=14690.0 s
#
# Primary Trigger Processing...
# Candidate 110, Trigger   1: xi=4.506 in   0.5 +(0.0) s Analysis @t=14784.5 s
#
# Primary Trigger Processing...
# Candidate 111, Trigger   1: xi=4.864 in   1.5 +(1.0) s Analysis @t=14882.0 s
#
# Primary Trigger Processing...
# Candidate 112, Trigger   1: xi=4.035 in  10.0 +(0.0) s Analysis @t=14950.0 s
#
# Primary Trigger Processing...
# Candidate 113, Trigger   2: xi=4.561 in   0.5 +(0.0) s Analysis @t=15084.5 s
#
# Primary Trigger Processing...
# Candidate 114, Trigger   1: xi=4.141 in  10.0 +(4.5) s Analysis @t=15465.5 s
#
# Primary Trigger Processing...
# Candidate 115, Trigger   1: xi=4.413 in   0.5 +(0.0) s Analysis @t=15546.0 s
#
# Primary Trigger Processing...
# Candidate 116, Trigger   1: xi=4.565 in   1.5 +(0.5) s Analysis @t=15611.5 s
#
# Primary Trigger Processing...
# Candidate 117, Trigger   1: xi=4.828 in   0.5 +(0.0) s Analysis @t=15706.5 s
#
# Primary Trigger Processing...
# Candidate 118, Trigger   2: xi=5.030 in   1.5 +(0.5) s Analysis @t=15769.0 s
#
# Primary Trigger Processing...
# Candidate 119, Trigger   2: xi=4.931 in   4.0 +(2.0) s Analysis @t=16068.0 s
#
# Primary Trigger Processing...
# Candidate 120, Trigger   1: xi=4.233 in   0.5 +(0.0) s Analysis @t=16238.5 s
#
# Primary Trigger Processing...
# Candidate 121, Trigger   1: xi=4.366 in   4.0 +(3.5) s Analysis @t=16370.5 s
#
# Primary Trigger Processing...
# Candidate 122, Trigger   1: xi=5.150 in   4.0 +(1.5) s Analysis @t=16604.5 s
#
# Primary Trigger Processing...
# Candidate 123, Trigger   2: xi=4.617 in   1.5 +(0.5) s Analysis @t=16660.0 s
#
# Primary Trigger Processing...
# Candidate 124, Trigger   2: xi=4.092 in   1.5 +(1.0) s Analysis @t=16772.0 s
#
# Primary Trigger Processing...
# Candidate 125, Trigger   1: xi=4.818 in   1.5 +(0.0) s Analysis @t=16989.0 s
#
# Primary Trigger Processing...
# Candidate 126, Trigger   1: xi=4.409 in  10.0 +(1.0) s Analysis @t=17229.0 s
#
# Primary Trigger Processing...
# Candidate 127, Trigger   1: xi=4.113 in   0.5 +(0.0) s Analysis @t=17400.0 s
#
# Primary Trigger Processing...
# Candidate 128, Trigger   1: xi=4.430 in   4.0 +(3.0) s Analysis @t=17567.0 s
#
# Primary Trigger Processing...
# Candidate 129, Trigger   2: xi=4.749 in   0.5 +(0.0) s Analysis @t=18076.0 s
#
# Primary Trigger Processing...
# Candidate 130, Trigger   1: xi=4.386 in   0.5 +(0.0) s Analysis @t=18351.0 s
#
# Primary Trigger Processing...
# Candidate 131, Trigger   1: xi=4.205 in   0.5 +(0.0) s Analysis @t=18460.0 s
#
# Primary Trigger Processing...
# Candidate 132, Trigger   1: xi=4.392 in   1.5 +(1.0) s Analysis @t=18519.5 s
#
# Primary Trigger Processing...
# Candidate 133, Trigger   1: xi=4.066 in   0.5 +(0.0) s Analysis @t=18565.5 s
#
# Primary Trigger Processing...
# Candidate 134, Trigger   1: xi=4.319 in   1.5 +(0.0) s Analysis @t=18642.0 s
#
# Primary Trigger Processing...
# Candidate 135, Trigger   1: xi=4.089 in   0.5 +(0.0) s Analysis @t=18826.5 s
#
# Primary Trigger Processing...
# Candidate 136, Trigger   1: xi=4.575 in   1.5 +(0.5) s Analysis @t=18946.0 s
#
# Primary Trigger Processing...
# Candidate 137, Trigger   1: xi=4.219 in   0.5 +(0.0) s Analysis @t=19152.0 s
#
# Primary Trigger Processing...
# Candidate 138, Trigger   2: xi=5.027 in   0.5 +(0.0) s Analysis @t=19415.5 s
#
# Basic Trigger Processing...
#  - Would perform muon correction
# Primary Trigger Processing...
# Candidate 139, Trigger   1: xi=6.293 in   0.5 +(0.0) s Analysis @t=19571.0 s
#
# Primary Trigger Processing...
# Candidate 140, Trigger   4: xi=5.172 in  10.0 +(1.0) s Analysis @t=19829.0 s
#
# Primary Trigger Processing...
# Candidate 141, Trigger   2: xi=4.764 in   0.5 +(0.0) s Analysis @t=19938.0 s
#
# Basic Trigger Processing...
#  - Would perform muon correction
# Primary Trigger Processing...
# Candidate 142, Trigger   1: xi=6.056 in   0.5 +(0.0) s Analysis @t=19977.0 s
#
# Primary Trigger Processing...
# Candidate 143, Trigger   1: xi=5.518 in   0.5 +(0.0) s Analysis @t=20013.5 s
#
# Primary Trigger Processing...
# Candidate 144, Trigger   1: xi=4.237 in   0.5 +(0.0) s Analysis @t=20049.5 s
#
# Primary Trigger Processing...
# Candidate 145, Trigger   1: xi=4.445 in   4.0 +(0.5) s Analysis @t=20153.5 s
#
# Primary Trigger Processing...
# Candidate 146, Trigger   2: xi=4.349 in   1.5 +(0.5) s Analysis @t=20195.5 s
#
# Primary Trigger Processing...
# Candidate 147, Trigger   1: xi=4.104 in   0.5 +(0.0) s Analysis @t=20595.0 s
#
# Primary Trigger Processing...
# Candidate 148, Trigger   2: xi=4.471 in   0.5 +(0.0) s Analysis @t=20688.5 s
#
# Primary Trigger Processing...
# Candidate 149, Trigger   2: xi=4.711 in   4.0 +(1.0) s Analysis @t=20961.0 s
#
# Primary Trigger Processing...
# Candidate 150, Trigger   1: xi=4.183 in   1.5 +(0.5) s Analysis @t=21058.0 s
#
# Primary Trigger Processing...
# Candidate 151, Trigger   1: xi=4.411 in   1.5 +(1.0) s Analysis @t=21209.0 s
#
# Primary Trigger Processing...
# Candidate 152, Trigger   1: xi=4.210 in   1.5 +(0.0) s Analysis @t=21517.5 s
# Primary Trigger Processing...
# Candidate 153, Trigger   2: xi=5.443 in   1.5 +(0.0) s Analysis @t=21580.5 s
#
# Primary Trigger Processing...
# Candidate 154, Trigger   1: xi=4.257 in   0.5 +(0.0) s Analysis @t=21855.0 s
#
# Primary Trigger Processing...
# Candidate 155, Trigger   3: xi=4.779 in   0.5 +(0.0) s Analysis @t=21991.5 s
#
# Primary Trigger Processing...
# Candidate 156, Trigger   1: xi=4.014 in   0.5 +(0.0) s Analysis @t=22095.5 s
#
# Primary Trigger Processing...
# Candidate 157, Trigger   4: xi=4.560 in   1.5 +(0.5) s Analysis @t=22226.5 s
#
# Primary Trigger Processing...
# Candidate 158, Trigger   1: xi=4.576 in  10.0 +(4.5) s Analysis @t=22275.5 s
#
# Primary Trigger Processing...
# Candidate 159, Trigger   1: xi=4.037 in   0.5 +(0.0) s Analysis @t=22409.0 s
#
# Primary Trigger Processing...
# Candidate 160, Trigger   1: xi=5.028 in   1.5 +(0.0) s Analysis @t=22482.0 s
#
# Primary Trigger Processing...
# Candidate 161, Trigger   1: xi=4.050 in   0.5 +(0.0) s Analysis @t=22818.5 s
#
# Primary Trigger Processing...
# Candidate 162, Trigger   1: xi=5.934 in   0.5 +(0.0) s Analysis @t=22870.0 s
#
# Primary Trigger Processing...
# Candidate 163, Trigger   1: xi=4.476 in   0.5 +(0.0) s Analysis @t=22924.0 s
#
# Primary Trigger Processing...
# Candidate 164, Trigger   2: xi=4.424 in   4.0 +(1.0) s Analysis @t=22961.0 s
#
# Primary Trigger Processing...
# Candidate 165, Trigger   2: xi=4.606 in   4.0 +(0.0) s Analysis @t=23050.0 s
#
# Primary Trigger Processing...
# Candidate 166, Trigger   1: xi=4.026 in   0.5 +(0.0) s Analysis @t=23119.5 s
#
# Basic Trigger Processing...
#  - Would perform muon correction
# Primary Trigger Processing...
# Candidate 167, Trigger   2: xi=6.575 in  10.0 +(0.5) s Analysis @t=23279.5 s
#
# Primary Trigger Processing...
# Candidate 168, Trigger   1: xi=4.385 in   1.5 +(1.0) s Analysis @t=23418.5 s
#
# Primary Trigger Processing...
# Candidate 169, Trigger   1: xi=4.257 in   0.5 +(0.0) s Analysis @t=23476.0 s
#
# Primary Trigger Processing...
# Candidate 170, Trigger   1: xi=4.132 in  10.0 +(7.5) s Analysis @t=23932.5 s
#
# Primary Trigger Processing...
# Candidate 171, Trigger   1: xi=5.318 in   4.0 +(2.0) s Analysis @t=24284.0 s
#
# Primary Trigger Processing...
# Candidate 172, Trigger   1: xi=4.050 in   4.0 +(0.5) s Analysis @t=24645.5 s
#
# Primary Trigger Processing...
# Candidate 173, Trigger   1: xi=5.531 in   0.5 +(0.0) s Analysis @t=24765.5 s
#
# Primary Trigger Processing...
# Candidate 174, Trigger   1: xi=4.352 in  10.0 +(5.5) s Analysis @t=24794.5 s
#
# Primary Trigger Processing...
# Candidate 175, Trigger   1: xi=4.498 in  10.0 +(1.0) s Analysis @t=24849.0 s
#
# Primary Trigger Processing...
# Candidate 176, Trigger   2: xi=4.489 in  10.0 +(6.5) s Analysis @t=24943.5 s
#
# Primary Trigger Processing...
# Candidate 177, Trigger   3: xi=4.774 in   4.0 +(0.0) s Analysis @t=25218.0 s
#
# Primary Trigger Processing...
# Candidate 178, Trigger   1: xi=4.308 in   0.5 +(0.0) s Analysis @t=25252.5 s
#
# Primary Trigger Processing...
# Candidate 179, Trigger   2: xi=5.419 in   0.5 +(0.0) s Analysis @t=25300.5 s
#
# Primary Trigger Processing...
# Candidate 180, Trigger   1: xi=4.122 in   0.5 +(0.0) s Analysis @t=25350.5 s
#
# Primary Trigger Processing...
# Candidate 181, Trigger   1: xi=4.314 in   0.5 +(0.0) s Analysis @t=25404.5 s
#
# Primary Trigger Processing...
# Candidate 182, Trigger   1: xi=4.592 in   0.5 +(0.0) s Analysis @t=25476.5 s
#
# Primary Trigger Processing...
# Candidate 183, Trigger   2: xi=4.422 in   0.5 +(0.0) s Analysis @t=25588.0 s
#
# Primary Trigger Processing...
# Candidate 184, Trigger   2: xi=4.682 in   1.5 +(0.0) s Analysis @t=25750.5 s
#
# Primary Trigger Processing...
# Candidate 185, Trigger   1: xi=4.426 in   1.5 +(1.0) s Analysis @t=25805.0 s
#
# Primary Trigger Processing...
# Candidate 186, Trigger   1: xi=4.190 in   0.5 +(0.0) s Analysis @t=26029.0 s
#
# Primary Trigger Processing...
# Candidate 187, Trigger   1: xi=4.139 in   0.5 +(0.0) s Analysis @t=26065.0 s
#
# Primary Trigger Processing...
# Candidate 188, Trigger   2: xi=5.144 in   1.5 +(1.0) s Analysis @t=26208.5 s
#
# Primary Trigger Processing...
# Candidate 189, Trigger   1: xi=4.474 in   1.5 +(0.5) s Analysis @t=26462.5 s
#
# Primary Trigger Processing...
# Candidate 190, Trigger   1: xi=4.142 in   0.5 +(0.0) s Analysis @t=26521.5 s
#
# Primary Trigger Processing...
# Candidate 191, Trigger   1: xi=4.099 in   0.5 +(0.0) s Analysis @t=26654.0 s
#
# Primary Trigger Processing...
# Candidate 192, Trigger   1: xi=4.030 in   1.5 +(1.0) s Analysis @t=26732.0 s
#
# Primary Trigger Processing...
# Candidate 193, Trigger   1: xi=4.373 in   0.5 +(0.0) s Analysis @t=26852.0 s
#
# Primary Trigger Processing...
# Candidate 194, Trigger   1: xi=4.087 in   0.5 +(0.0) s Analysis @t=27108.0 s
#
# Primary Trigger Processing...
# Candidate 195, Trigger   1: xi=5.449 in   0.5 +(0.0) s Analysis @t=27195.0 s
#
# Primary Trigger Processing...
# Candidate 196, Trigger   1: xi=4.318 in   0.5 +(0.0) s Analysis @t=27297.0 s
#
# Primary Trigger Processing...
# Candidate 197, Trigger   1: xi=4.070 in   0.5 +(0.0) s Analysis @t=27477.5 s
#
# Primary Trigger Processing...
# Candidate 198, Trigger   1: xi=4.536 in   4.0 +(0.0) s Analysis @t=27630.0 s
#
# Primary Trigger Processing...
# Candidate 199, Trigger   1: xi=4.005 in   0.5 +(0.0) s Analysis @t=27680.5 s
#
# Primary Trigger Processing...
# Candidate 200, Trigger   2: xi=5.159 in   0.5 +(0.0) s Analysis @t=27748.5 s
#
# Primary Trigger Processing...
# Candidate 201, Trigger   1: xi=4.200 in   1.5 +(1.0) s Analysis @t=27804.5 s
#
# Primary Trigger Processing...
# Candidate 202, Trigger   1: xi=4.564 in   0.5 +(0.0) s Analysis @t=27852.5 s
#
# Primary Trigger Processing...
# Candidate 203, Trigger   1: xi=4.693 in   4.0 +(1.5) s Analysis @t=27936.5 s
#
# Primary Trigger Processing...
# Candidate 204, Trigger   1: xi=4.029 in   1.5 +(0.0) s Analysis @t=27981.0 s

# %%
for i, search in enumerate(ana.analyses):
    idc_debug = {
        'eod': search.idx_eod,
        'bgl': search.idx_bgl,
        'exl': search.idx_exl,
        'sw':  search.idx_sw,
        'ext': search.idx_ext,
        'bgt': search.idx_bgt
    }
    
    print(f"\nSearch #{i:<2d} :{search.binsize/1e3:4.1f} +{search.offset/1e3:<4.1f}s")
    for key, val in idc_debug.items():
        print(f"{key:>10s} : {val:<5d}")
# Out:
# Search #0  : 0.5 +0.0 s
#        eod : 1319
#        bgl : 719
#        exl : 689
#         sw : 688
#        ext : 658
#        bgt : 58
#
# Search #1  : 1.5 +0.0 s
#        eod : 1319
#        bgl : 719
#        exl : 689
#         sw : 686
#        ext : 656
#        bgt : 56
#
# Search #2  : 1.5 +0.5 s
#        eod : 1318
#        bgl : 718
#        exl : 688
#         sw : 685
#        ext : 655
#        bgt : 55
#
# Search #3  : 1.5 +1.0 s
#        eod : 1317
#        bgl : 717
#        exl : 687
#         sw : 684
#        ext : 654
#        bgt : 54
#
# Search #4  : 4.0 +0.0 s
#        eod : 1319
#        bgl : 719
#        exl : 689
#         sw : 681
#        ext : 651
#        bgt : 51
#
# Search #5  : 4.0 +0.5 s
#        eod : 1318
#        bgl : 718
#        exl : 688
#         sw : 680
#        ext : 650
#        bgt : 50
#
# Search #6  : 4.0 +1.0 s
#        eod : 1317
#        bgl : 717
#        exl : 687
#         sw : 679
#        ext : 649
#        bgt : 49
#
# Search #7  : 4.0 +1.5 s
#        eod : 1316
#        bgl : 716
#        exl : 686
#         sw : 678
#        ext : 648
#        bgt : 48
#
# Search #8  : 4.0 +2.0 s
#        eod : 1315
#        bgl : 715
#        exl : 685
#         sw : 677
#        ext : 647
#        bgt : 47
#
# Search #9  : 4.0 +2.5 s
#        eod : 1314
#        bgl : 714
#        exl : 684
#         sw : 676
#        ext : 646
#        bgt : 46
#
# Search #10 : 4.0 +3.0 s
#        eod : 1313
#        bgl : 713
#        exl : 683
#         sw : 675
#        ext : 645
#        bgt : 45
#
# Search #11 : 4.0 +3.5 s
#        eod : 1312
#        bgl : 712
#        exl : 682
#         sw : 674
#        ext : 644
#        bgt : 44
#
# Search #12 :10.0 +0.0 s
#        eod : 1319
#        bgl : 719
#        exl : 689
#         sw : 669
#        ext : 639
#        bgt : 39
#
# Search #13 :10.0 +0.5 s
#        eod : 1318
#        bgl : 718
#        exl : 688
#         sw : 668
#        ext : 638
#        bgt : 38
#
# Search #14 :10.0 +1.0 s
#        eod : 1317
#        bgl : 717
#        exl : 687
#         sw : 667
#        ext : 637
#        bgt : 37
#
# Search #15 :10.0 +1.5 s
#        eod : 1316
#        bgl : 716
#        exl : 686
#         sw : 666
#        ext : 636
#        bgt : 36
#
# Search #16 :10.0 +2.0 s
#        eod : 1315
#        bgl : 715
#        exl : 685
#         sw : 665
#        ext : 635
#        bgt : 35
#
# Search #17 :10.0 +2.5 s
#        eod : 1314
#        bgl : 714
#        exl : 684
#         sw : 664
#        ext : 634
#        bgt : 34
#
# Search #18 :10.0 +3.0 s
#        eod : 1313
#        bgl : 713
#        exl : 683
#         sw : 663
#        ext : 633
#        bgt : 33
#
# Search #19 :10.0 +3.5 s
#        eod : 1312
#        bgl : 712
#        exl : 682
#         sw : 662
#        ext : 632
#        bgt : 32
#
# Search #20 :10.0 +4.0 s
#        eod : 1311
#        bgl : 711
#        exl : 681
#         sw : 661
#        ext : 631
#        bgt : 31
#
# Search #21 :10.0 +4.5 s
#        eod : 1310
#        bgl : 710
#        exl : 680
#         sw : 660
#        ext : 630
#        bgt : 30
#
# Search #22 :10.0 +5.0 s
#        eod : 1309
#        bgl : 709
#        exl : 679
#         sw : 659
#        ext : 629
#        bgt : 29
#
# Search #23 :10.0 +5.5 s
#        eod : 1308
#        bgl : 708
#        exl : 678
#         sw : 658
#        ext : 628
#        bgt : 28
#
# Search #24 :10.0 +6.0 s
#        eod : 1307
#        bgl : 707
#        exl : 677
#         sw : 657
#        ext : 627
#        bgt : 27
#
# Search #25 :10.0 +6.5 s
#        eod : 1306
#        bgl : 706
#        exl : 676
#         sw : 656
#        ext : 626
#        bgt : 26
#
# Search #26 :10.0 +7.0 s
#        eod : 1305
#        bgl : 705
#        exl : 675
#         sw : 655
#        ext : 625
#        bgt : 25
#
# Search #27 :10.0 +7.5 s
#        eod : 1304
#        bgl : 704
#        exl : 674
#         sw : 654
#        ext : 624
#        bgt : 24
#
# Search #28 :10.0 +8.0 s
#        eod : 1303
#        bgl : 703
#        exl : 673
#         sw : 653
#        ext : 623
#        bgt : 23
#
# Search #29 :10.0 +8.5 s
#        eod : 1302
#        bgl : 702
#        exl : 672
#         sw : 652
#        ext : 622
#        bgt : 22
#
# Search #30 :10.0 +9.0 s
#        eod : 1301
#        bgl : 701
#        exl : 671
#         sw : 651
#        ext : 621
#        bgt : 21
#
# Search #31 :10.0 +9.5 s
#        eod : 1300
#        bgl : 700
#        exl : 670
#         sw : 650
#        ext : 620
#        bgt : 20

# %%
for i, search in enumerate(ana.analyses):
    idc_debug = {
        'add_bgl': search._idx_addbgl[[0,-1]],
        'sub_bgl': search._idx_subbgl[[0,-1]],
        'add_sw': search._idx_addsw[[0,-1]],
        'sub_sw': search._idx_subsw[[0,-1]],
        'add_bgt': search._idx_addbgt[[0,-1]],
        'sub_bgt':  search._idx_subbgt[[0,-1]],
    }
    
    print(f"\nSearch #{i:<2d} :{search.binsize/1e3:4.1f} +{search.offset/1e3:<4.1f}s")
    for key, val in idc_debug.items():
        print(f"{key:>10s} : {val[0]:>5d} .. {val[1]:<5d}")
# Out:
# Search #0  : 0.5 +0.0 s
#    add_bgl :  1318 .. 1318
#    sub_bgl :   718 .. 718
#     add_sw :   688 .. 688
#     sub_sw :   687 .. 687
#    add_bgt :   657 .. 657
#    sub_bgt :    57 .. 57
#
# Search #1  : 1.5 +0.0 s
#    add_bgl :  1316 .. 1318
#    sub_bgl :   716 .. 718
#     add_sw :   686 .. 688
#     sub_sw :   683 .. 685
#    add_bgt :   653 .. 655
#    sub_bgt :    53 .. 55
#
# Search #2  : 1.5 +0.5 s
#    add_bgl :  1315 .. 1317
#    sub_bgl :   715 .. 717
#     add_sw :   685 .. 687
#     sub_sw :   682 .. 684
#    add_bgt :   652 .. 654
#    sub_bgt :    52 .. 54
#
# Search #3  : 1.5 +1.0 s
#    add_bgl :  1314 .. 1316
#    sub_bgl :   714 .. 716
#     add_sw :   684 .. 686
#     sub_sw :   681 .. 683
#    add_bgt :   651 .. 653
#    sub_bgt :    51 .. 53
#
# Search #4  : 4.0 +0.0 s
#    add_bgl :  1311 .. 1318
#    sub_bgl :   711 .. 718
#     add_sw :   681 .. 688
#     sub_sw :   673 .. 680
#    add_bgt :   643 .. 650
#    sub_bgt :    43 .. 50
#
# Search #5  : 4.0 +0.5 s
#    add_bgl :  1310 .. 1317
#    sub_bgl :   710 .. 717
#     add_sw :   680 .. 687
#     sub_sw :   672 .. 679
#    add_bgt :   642 .. 649
#    sub_bgt :    42 .. 49
#
# Search #6  : 4.0 +1.0 s
#    add_bgl :  1309 .. 1316
#    sub_bgl :   709 .. 716
#     add_sw :   679 .. 686
#     sub_sw :   671 .. 678
#    add_bgt :   641 .. 648
#    sub_bgt :    41 .. 48
#
# Search #7  : 4.0 +1.5 s
#    add_bgl :  1308 .. 1315
#    sub_bgl :   708 .. 715
#     add_sw :   678 .. 685
#     sub_sw :   670 .. 677
#    add_bgt :   640 .. 647
#    sub_bgt :    40 .. 47
#
# Search #8  : 4.0 +2.0 s
#    add_bgl :  1307 .. 1314
#    sub_bgl :   707 .. 714
#     add_sw :   677 .. 684
#     sub_sw :   669 .. 676
#    add_bgt :   639 .. 646
#    sub_bgt :    39 .. 46
#
# Search #9  : 4.0 +2.5 s
#    add_bgl :  1306 .. 1313
#    sub_bgl :   706 .. 713
#     add_sw :   676 .. 683
#     sub_sw :   668 .. 675
#    add_bgt :   638 .. 645
#    sub_bgt :    38 .. 45
#
# Search #10 : 4.0 +3.0 s
#    add_bgl :  1305 .. 1312
#    sub_bgl :   705 .. 712
#     add_sw :   675 .. 682
#     sub_sw :   667 .. 674
#    add_bgt :   637 .. 644
#    sub_bgt :    37 .. 44
#
# Search #11 : 4.0 +3.5 s
#    add_bgl :  1304 .. 1311
#    sub_bgl :   704 .. 711
#     add_sw :   674 .. 681
#     sub_sw :   666 .. 673
#    add_bgt :   636 .. 643
#    sub_bgt :    36 .. 43
#
# Search #12 :10.0 +0.0 s
#    add_bgl :  1299 .. 1318
#    sub_bgl :   699 .. 718
#     add_sw :   669 .. 688
#     sub_sw :   649 .. 668
#    add_bgt :   619 .. 638
#    sub_bgt :    19 .. 38
#
# Search #13 :10.0 +0.5 s
#    add_bgl :  1298 .. 1317
#    sub_bgl :   698 .. 717
#     add_sw :   668 .. 687
#     sub_sw :   648 .. 667
#    add_bgt :   618 .. 637
#    sub_bgt :    18 .. 37
#
# Search #14 :10.0 +1.0 s
#    add_bgl :  1297 .. 1316
#    sub_bgl :   697 .. 716
#     add_sw :   667 .. 686
#     sub_sw :   647 .. 666
#    add_bgt :   617 .. 636
#    sub_bgt :    17 .. 36
#
# Search #15 :10.0 +1.5 s
#    add_bgl :  1296 .. 1315
#    sub_bgl :   696 .. 715
#     add_sw :   666 .. 685
#     sub_sw :   646 .. 665
#    add_bgt :   616 .. 635
#    sub_bgt :    16 .. 35
#
# Search #16 :10.0 +2.0 s
#    add_bgl :  1295 .. 1314
#    sub_bgl :   695 .. 714
#     add_sw :   665 .. 684
#     sub_sw :   645 .. 664
#    add_bgt :   615 .. 634
#    sub_bgt :    15 .. 34
#
# Search #17 :10.0 +2.5 s
#    add_bgl :  1294 .. 1313
#    sub_bgl :   694 .. 713
#     add_sw :   664 .. 683
#     sub_sw :   644 .. 663
#    add_bgt :   614 .. 633
#    sub_bgt :    14 .. 33
#
# Search #18 :10.0 +3.0 s
#    add_bgl :  1293 .. 1312
#    sub_bgl :   693 .. 712
#     add_sw :   663 .. 682
#     sub_sw :   643 .. 662
#    add_bgt :   613 .. 632
#    sub_bgt :    13 .. 32
#
# Search #19 :10.0 +3.5 s
#    add_bgl :  1292 .. 1311
#    sub_bgl :   692 .. 711
#     add_sw :   662 .. 681
#     sub_sw :   642 .. 661
#    add_bgt :   612 .. 631
#    sub_bgt :    12 .. 31
#
# Search #20 :10.0 +4.0 s
#    add_bgl :  1291 .. 1310
#    sub_bgl :   691 .. 710
#     add_sw :   661 .. 680
#     sub_sw :   641 .. 660
#    add_bgt :   611 .. 630
#    sub_bgt :    11 .. 30
#
# Search #21 :10.0 +4.5 s
#    add_bgl :  1290 .. 1309
#    sub_bgl :   690 .. 709
#     add_sw :   660 .. 679
#     sub_sw :   640 .. 659
#    add_bgt :   610 .. 629
#    sub_bgt :    10 .. 29
#
# Search #22 :10.0 +5.0 s
#    add_bgl :  1289 .. 1308
#    sub_bgl :   689 .. 708
#     add_sw :   659 .. 678
#     sub_sw :   639 .. 658
#    add_bgt :   609 .. 628
#    sub_bgt :     9 .. 28
#
# Search #23 :10.0 +5.5 s
#    add_bgl :  1288 .. 1307
#    sub_bgl :   688 .. 707
#     add_sw :   658 .. 677
#     sub_sw :   638 .. 657
#    add_bgt :   608 .. 627
#    sub_bgt :     8 .. 27
#
# Search #24 :10.0 +6.0 s
#    add_bgl :  1287 .. 1306
#    sub_bgl :   687 .. 706
#     add_sw :   657 .. 676
#     sub_sw :   637 .. 656
#    add_bgt :   607 .. 626
#    sub_bgt :     7 .. 26
#
# Search #25 :10.0 +6.5 s
#    add_bgl :  1286 .. 1305
#    sub_bgl :   686 .. 705
#     add_sw :   656 .. 675
#     sub_sw :   636 .. 655
#    add_bgt :   606 .. 625
#    sub_bgt :     6 .. 25
#
# Search #26 :10.0 +7.0 s
#    add_bgl :  1285 .. 1304
#    sub_bgl :   685 .. 704
#     add_sw :   655 .. 674
#     sub_sw :   635 .. 654
#    add_bgt :   605 .. 624
#    sub_bgt :     5 .. 24
#
# Search #27 :10.0 +7.5 s
#    add_bgl :  1284 .. 1303
#    sub_bgl :   684 .. 703
#     add_sw :   654 .. 673
#     sub_sw :   634 .. 653
#    add_bgt :   604 .. 623
#    sub_bgt :     4 .. 23
#
# Search #28 :10.0 +8.0 s
#    add_bgl :  1283 .. 1302
#    sub_bgl :   683 .. 702
#     add_sw :   653 .. 672
#     sub_sw :   633 .. 652
#    add_bgt :   603 .. 622
#    sub_bgt :     3 .. 22
#
# Search #29 :10.0 +8.5 s
#    add_bgl :  1282 .. 1301
#    sub_bgl :   682 .. 701
#     add_sw :   652 .. 671
#     sub_sw :   632 .. 651
#    add_bgt :   602 .. 621
#    sub_bgt :     2 .. 21
#
# Search #30 :10.0 +9.0 s
#    add_bgl :  1281 .. 1300
#    sub_bgl :   681 .. 700
#     add_sw :   651 .. 670
#     sub_sw :   631 .. 650
#    add_bgt :   601 .. 620
#    sub_bgt :     1 .. 20
#
# Search #31 :10.0 +9.5 s
#    add_bgl :  1280 .. 1299
#    sub_bgl :   680 .. 699
#     add_sw :   650 .. 669
#     sub_sw :   630 .. 649
#    add_bgt :   600 .. 619
#    sub_bgt :     0 .. 19
